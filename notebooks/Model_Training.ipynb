# %% [markdown]
# # 🩺 Predictive Pulse — Model Training Notebook
#
# Interactive notebook for training and comparing hypertension classification models.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import joblib
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Run Preprocessing Pipeline

# %%
from src.preprocess import preprocess_pipeline
X_train, X_test, y_train, y_test = preprocess_pipeline()

# %% [markdown]
# ## 2. Feature Engineering

# %%
from src.feature_engineering import feature_engineering_pipeline
X_train, X_test, y_train = feature_engineering_pipeline()

# %% [markdown]
# ## 3. Train Models

# %%
from src.train import training_pipeline
results, best_name = training_pipeline()
print(f'\nBest model: {best_name}')

# %% [markdown]
# ## 4. Evaluate Models

# %%
from src.evaluate import evaluation_pipeline
results_df = evaluation_pipeline()
results_df

# %% [markdown]
# ## 5. Demo Predictions

# %%
from src.predict import HypertensionPredictor

predictor = HypertensionPredictor()

# Normal patient
result = predictor.predict({
    'age': 28, 'gender': 'Female', 'bmi': 22.0,
    'systolic_bp': 115, 'diastolic_bp': 72,
    'cholesterol': 180, 'glucose': 85,
    'smoking': 'Never', 'alcohol': 'None',
    'physical_activity': 'High', 'diabetes': 0, 'medication': 0
})
print('Normal patient:', result)

# %%
# Crisis patient
result = predictor.predict({
    'age': 68, 'gender': 'Male', 'bmi': 34.0,
    'systolic_bp': 190, 'diastolic_bp': 125,
    'cholesterol': 280, 'glucose': 180,
    'smoking': 'Current', 'alcohol': 'Heavy',
    'physical_activity': 'Low', 'diabetes': 1, 'medication': 1
})
print('Crisis patient:', result)
